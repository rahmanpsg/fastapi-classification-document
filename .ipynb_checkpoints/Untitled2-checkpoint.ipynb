# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
df = pd.read_csv("data.csv")

df.head()
# Out:
#          prodi        nim                 nama  \
# 0    manajemen  215350030  Andi Adriani Paesal
# 1    manajemen  215350034            Riskianti
# 2    manajemen  215350007       Iis Faradillah
# 3    manajemen  215350015            Ardiyanto
# 4  pembangunan  213210027              Junaedi
#
#                                              dokumen
# 0  1 jurnal economos feb um parepare pengaruh mot...
# 1  efektivitas profitabilitas guna modal kerja pa...
# 2  1 jurnal economos feb um parepare draft templa...
# 3  1 jurnal economos feb um parepare pengaruh bia...
# 4  evaluasi kerja badan rencana bangun daerah bap...

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(df.dokumen[:20])
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
neigh = NearestNeighbors(n_neighbors=3, n_jobs=-1) 
neigh.fit(X_train_tfidf)
# Out:
# NearestNeighbors(n_jobs=-1, n_neighbors=3)

# %%
test=["jurnal daya kwh meter komunikasi"]
X_test_counts = count_vect.transform(test)

X_test_tfidf = tfidf_transformer.transform(X_test_counts)

res = neigh.kneighbors(X_test_tfidf)

res
# Out:
# (array([[1.05692823, 1.38643708, 1.38671919]]), array([[16, 15,  9]]))

# %%
X_train_tfidf
# Out:
# <20x7749 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16939 stored elements in Compressed Sparse Row format>

# %%
count_vect.get_feature_names()
# Out:
# ['000',
#  '0000',
#  '0001',
#  '0003',
#  '0008',
#  '000b',
#  '001',
#  '003',
#  '005',
#  '008',
#  '010117',
#  '010318',
#  '010518',
#  '0117',
#  '012',
#  '01217',
#  '020117',
#  '020217',
#  '020418',
#  '030317',
#  '030318',
#  '030417',
#  '030517',
#  '030618',
#  '034riskiantisipigmailcom',
#  '035',
#  '040',
#  '040118',
#  '040217',
#  '040418',
#  '0476',
#  '0478',
#  '050117',
#  '050318',
#  '050617',
#  '056',
#  '0599',
#  '060',
#  '060317',
#  '060618',
#  '066',
#  '0690a',
#  '070117',
#  '070318',
#  '0738',
#  '0740',
#  '0765',
#  '080317',
#  '080417',
#  '080517',
#  '080518',
#  '080618',
#  '090318',
#  '10',
#  '100',
#  '1000',
#  '100000',
#  '1000000',
#  '100000kg',
#  '1001',
#  '100117',
#  '1001x',
#  '11',
#  '110117',
#  '110617',
#  '110618',
#  '1122',
#  '112200000',
#  '12',
#  '120117',
#  '120118',
#  '1201217',
#  '120417',
#  '120518',
#  '123',
#  '1233',
#  '124',
#  '125',
#  '128',
#  '128910000',
#  '129138',
#  '13',
#  '130317',
#  '130318',
#  '130418',
#  '137121',
#  '137612448',
#  '14',
#  '140117',
#  '140517',
#  '14100000',
#  '15',
#  '15000',
#  '1500000',
#  '15000000',
#  '150318',
#  '1506',
#  '155',
#  '15500000',
#  '1584',
#  '1588',
#  '16',
#  '16000000',
#  '1602',
#  '1613',
#  '1645',
#  '16625',
#  '1664',
#  '1666',
#  '17',
#  '170317',
#  '170417',
#  '170418',
#  '170617',
#  '170618',
#  '18',
#  '180000',
#  '18000000',
#  '180118',
#  '18600000',
#  '1890',
#  '19',
#  '190117',
#  '192',
#  '19200000',
#  '1950000',
#  '1963',
#  '196300000',
#  '1998',
#  '1constant',
#  '20',
#  '200',
#  '2000',
#  '2001',
#  '20017',
#  '2002',
#  '200217',
#  '2003',
#  '200317',
#  '2004',
#  '2005',
#  '2006',
#  '200615',
#  '200617',
#  '20062011',
#  '2007',
#  '200778',
#  '200789',
#  '2008',
#  '2008141',
#  '20082012',
#  '2008287',
#  '2009',
#  '200918',
#  '2010',
#  '2010000',
#  '2011',
#  '201147',
#  '2012',
#  '2012378',
#  '2013',
#  '2014',
#  '2014115rasio',
#  '2014406',
#  '2015',
#  '2016pengaruh',
#  '2017',
#  '2018',
#  '20182019',
#  '2019',
#  '2020',
#  '2024',
#  '20700000',
#  '21',
#  '2100000',
#  '210217',
#  '22',
#  '220117',
#  '220317',
#  '220318',
#  '220417',
#  '2250000',
#  '23',
#  '230117',
#  '230318',
#  '230518',
#  '230617',
#  '232',
#  '23200000',
#  '23700000',
#  '23910000',
#  '24',
#  '2400000',
#  '24000000',
#  '240217',
#  '240418',
#  '242',
#  '24200000',
#  '248',
#  '25',
#  '250',
#  '2500000',
#  '25000000',
#  '250317',
#  '250417',
#  '26',
#  '260118',
#  '2640000',
#  '266',
#  '26600000',
#  '27',
#  '2700000',
#  '270217',
#  '270218',
#  '270518',
#  '2759',
#  '28',
#  '280217',
#  '280318',
#  '286',
#  '28600000',
#  '29',
#  '290117',
#  '290118',
#  '290617',
#  '296',
#  '29600000',
#  '298',
#  '29800000',
#  '29800000pada',
#  '2harga',
#  '2tailed',
#  '30',
#  '30000',
#  '3000000',
#  '30000kg',
#  '300117',
#  '300317',
#  '300417',
#  '31',
#  '32',
#  '3200000',
#  '328',
#  '32800000',
#  '33',
#  '3300000',
#  '34',
#  '35',
#  '3500000',
#  '3500000pada',
#  '357',
#  '35700000',
#  '36',
#  '3600000',
#  '37',
#  '370962',
#  '38',
#  '3800000',
#  '39',
#  '398',
#  '39800000',
#  '40',
#  '4000000',
#  '41',
#  '42',
#  '4200000',
#  '4297',
#  '43',
#  '4385',
#  '44',
#  '4400000',
#  '45',
#  '4500000',
#  '46',
#  '4600000',
#  '4620000',
#  '463',
#  '47',
#  '470',
#  '4700000',
#  '476',
#  '48',
#  '4800000',
#  '485',
#  '49',
#  '4p',
#  '50',
#  '500',
#  '5000000',
#  '51',
#  '510',
#  '511',
#  '512',
#  '513',
#  '514',
#  '52',
#  '5213',
#  '524',
#  '5280000',
#  '53',
#  '54',
#  '55',
#  '550',
#  '5500000',
#  '56',
#  '57',
#  '58',
#  '585',
#  '59',
#  '5953',
#  '600',
#  '600000',
#  '6056',
#  '620',
#  '64',
#  '65',
#  '67',
#  '690',
#  '690a',
#  '69300000',
#  '70',
#  '700',
#  '701',
#  '738',
#  '74',
#  '740',
#  '75',
#  '7500000',
#  '765',
#  '78',
#  '797',
#  '80',
#  '83',
#  '84',
#  '85',
#  '87',
#  '890',
#  '90',
#  '9177',
#  '93418',
#  '93474',
#  '94',
#  '95',
#  '98665',
#  '99',
#  'abdul',
#  'abdullah',
#  'abon',
#  'about',
#  'abstract',
#  'abstrak',
#  'abtractshould',
#  'achieved',
#  'acu',
#  'ada',
#  'adalah',
#  'adapun',
#  'adi',
#  'adira',
#  'adjusted',
#  'administrasi',
#  'adriani',
#  'advancement',
#  'advisor',
#  'aga',
#  'agama',
#  'agency',
#  'agung',
#  'agustina',
#  'aims',
#  'air',
#  'ajar',
#  'aju',
#  'akan',
#  'akhir',
#  'akibat',
#  'aksara',
#  'akselerasi',
#  'aktif',
#  'aktiva',
#  'aktualisasi',
#  'akutansi',
#  'alamat',
#  'alami',
#  'alat',
#  'alfabeta',
#  'alpha',
#  'alumni',
#  'aman',
#  'amat',
#  'ambil',
#  'amstrong',
#  'anak',
#  'analis',
#  'analisis',
#  'analisis2017',
#  'analsis',
#  'analysis',
#  'ancam',
#  'and',
#  'andi',
#  'andiadriani50gmailcom',
#  'anggap',
#  'anggar',
#  'anggota',
#  'angka',
#  'angkaangkadata',
#  'angkat',
#  'angket',
#  'angkut',
#  'angota',
#  'animo',
#  'anova',
#  'anovaa',
#  'antar',
#  'antara',
#  'apa',
#  'apabila',
#  'aplikasi',
#  'appraisal',
#  'apr',
#  'april',
#  'arah',
#  'ardhani',
#  'are',
#  'area',
#  'arikunto',
#  'arodhiskara',
#  'aroma',
#  'arsip',
#  'arti',
#  'aryani',
#  'as',
#  'asal',
#  'aset',
#  'asli',
#  'aspirasi',
#  'assets',
#  'aswaja',
#  'at',
#  'atas',
#  'atau',
#  'attitudes',
#  'atupun',
#  'atur',
#  'awal',
#  'awards',
#  'awas',
#  'awet',
#  'baca',
#  'bacukiki',
#  'bagai',
#  'bagaimana',
#  'bagi',
#  'bahan',
#  'bahas',
#  'bahwa',
#  'baik',
#  'baku',
#  'bakurp',
#  'bal',
#  'balas',
#  'balik',
#  'banding',
#  'bandung',
#  'bangkit',
#  'bangun',
#  'bantu',
#  'banyak',
#  'bapak',
#  'barang',
#  'barat',
#  'baron',
#  'baru',
#  'bas',
#  'based',
#  'batam',
#  'batas',
#  'bau',
#  'baur',
#  'bawa',
#  'bawah',
#  'bawang',
#  'bayar',
#  'be',
#  'beasiswa',
#  'beban',
#  'bebas',
#  'beberapa',
#  'because',
#  'bed',
#  'beda',
#  'began',
#  'bei',
#  'bekal',
#  'belakang',
#  'beli',
#  'belum',
#  'benah',
#  'benar',
#  'benarbenar',
#  'benda',
#  'bening',
#  'bentuk',
#  'bentukbentuk',
#  'berapa',
#  'berdasarakan',
#  'beri',
#  'bermacammacam',
#  'bersamasama',
#  'bersih',
#  'besar',
#  'beta',
#  'betul',
#  'between',
#  'beyond',
#  'bhn',
#  'biasa',
#  'biaya',
#  'bidang',
#  'bijak',
#  'bila',
#  'bilamana',
#  'bilang',
#  'bimbing',
#  'bina',
#  'bintang',
#  'biodiversity',
#  'bisa',
#  'bisnis',
#  'bogor',
#  'boleh',
#  'bonus',
#  'bonuses',
#  'bpfe',
#  'brief',
#  'brotoharjo',
#  'buah',
#  'buat',
#  'budgetcosteffectivemanagement',
#  'buka',
#  'bukti',
#  'buku',
#  'bulan',
#  'bumbubumbunya',
#  'bumi',
#  'bungkus',
#  'bungkusanukuran',
#  'burhanuddin',
#  'bursa',
#  'buruk',
#  'business',
#  'busuk',
#  'butirbutir',
#  'butuh',
#  'bx',
#  'by',
#  'cabang',
#  'cakap',
#  'calon',
#  'caloncalon',
#  'calyptra',
#  'camat',
#  'can',
#  'capa',
#  'capai',
#  'capital',
#  'cappa',
#  'caps',
#  'cara',
#  'career',
#  'cari',
#  'carried',
#  'catat',
#  'cepat',
#  'cermat',
#  'cipta',
#  'ciri',
#  'citra',
#  'city',
#  'clear',
#  'coaching',
#  'coastal',
#  'coba',
#  'cocok',
#  'coefficients',
#  'coefficientsa',
#  'collection',
#  'comment',
#  'companys',
#  'competence',
#  'concluded',
#  'conclusions',
#  'consists',
#  'constant',
#  'contoh',
#  'correlation',
#  'crobach',
#  'cronbach',
#  'cronbachs',
#  'cukup',
#  'cv',
#  'd3',
#  'daerah',
#  'daftar',
#  'dagang',
#  'daging',
#  'dahulu',
#  'dahuri',
#  'dalam',
#  'dalamluar',
#  'damanik',
#  'dampak',
#  'dan',
#  'danang',
#  'dandy',
#  'dapat',
#  'daratdan',
#  'dari',
#  'dasar',
#  'data',
#  'datang',
#  'datasumber',
#  'daun',
#  'daya',
#  'dearlina',
#  'decreased',
#  'dekat',
#  'deleted',
#  'demikian',
#  'dengan',
#  'dengar',
#  'depan',
#  'department',
#  'dependent',
#  'describe',
#  'descriptive',
#  'deskripsi',
#  'deskriptif',
#  'determinasi',
#  'determine',
#  'df',
#  'dharma',
#  'di',
#  'didik',
#  'diingikan',
#  'diklat',
#  'dikti',
#  'dinamika',
#  'dinas',
#  'diploma',
#  'dipoduksi',
#  'diponegoro',
#  'direct',
#  'direction',
#  'diri',
#  'disampikan',
#  'discussion',
#  'diselesaikanulasan',
#  'disiplin',
#  'diskusi',
#  'distribusi',
#  'distribution',
#  'distributor',
#  'ditugasakan',
#  'documentation',
#  'dokumen',
#  'dokumendokumen',
#  'dokumentasi',
#  'dokumenter',
#  'dominasi',
#  'dorong',
#  'download',
#  'draft',
#  'dua',
#  'duduk',
#  'dukung',
#  'dunia',
#  'dwi',
#  'economics',
#  'economos',
#  'edar',
#  'edisi',
#  'education',
#  'edwin',
#  'efek',
#  'efektif',
#  'efektivitas',
#  'efesien',
#  'effect',
#  'effectiveness',
#  'efisien',
#  'eka',
#  'ekonomi',
#  'ekonomis',
#  'eksklusif',
#  'ekslusif',
#  'eksploitasi',
#  'ekuitas',
#  'ekuitasrp',
#  'elektronics',
#  'email',
#  'emil',
#  'emmyah',
#  'empat',
#  'employee',
#  'employees',
#  'enak',
#  'enam',
#  'encouragement',
#  'end',
#  'enem',
#  'english',
#  'environment',
#  'environmental',
#  'equity',
#  'erat',
#  'error',
#  'erti',
#  'essay',
#  'estate',
#  'estimate',
#  'evaluasi',
#  'executive',
#  'faculty',
#  'faktor',
#  'fakultas',
#  'fakultras',
#  'faradillah',
#  'feb',
#  'februari',
#  'february',
#  'fidiakui',
#  'finance',
#  'fipengaruh',
#  'fisik',
#  'fisip',
#  'fitanpa',
#  'fiummifl',
#  'fiuntuk',
#  'flpengaruh',
#  'follows',
#  'for',
#  'formal',
#  'formula',
#  'frekuensi',
#  'fungsi',
#  'future',
#  'gairah',
#  'gaji',
#  'gali',
#  'galung',
#  'gambar',
#  'gantung',
#  'garis',
#  'gerak',
#  'ghozali',
#  'giat',
#  'gitosudarmo',
#  'given',
#  'go',
#  'golong',
#  'golonganpangkat',
#  'goreng',
#  'grafik',
#  'grafindo',
#  'gramedia',
#  'gratis',
#  'gross',
#  'guna',
#  'guru',
#  'h1',
#  'habis',
#  'had',
#  'hadap',
#  'hakikat',
#  'hal',
#  'handal',
#  'handoko',
#  'handoyo',
#  'handycraft',
#  'hani',
#  'hanya',
#  'harap',
#  'harga',
#  'hari',
#  'hartono',
#  'harus',
#  'has',
#  'hasibuan',
#  'hasil',
#  'hayati',
#  'heidjrachman',
#  'henti',
#  'herna',
#  'herry',
#  'hidayat',
#  'hidup',
#  'hilir',
#  'hingga',
#  'hipotesis',
#  'historis',
#  'hitung',
#  'hlim',
#  'ho',
#  'hormaingat',
#  'hotel',
#  'hours',
#  'hrg',
#  'httpwww',
#  'hubung',
#  'hukum',
#  'hulu',
#  'husein',
#  'husnan',
#  'ialah',
#  'ibu',
#  'id',
#  'if',
#  'ii',
#  'iii',
#  'iis',
#  'iisfaradillah1212gmailcom',
#  'ikan',
#  'ikanpada',
#  'ikat',
#  'ikut',
#  'ilmiah',
#  'ilmu',
#  'image',
#  'imam',
#  'imbal',
#  'imfortance',
#  'implementasi',
#  'implemented',
#  'importance',
#  'in',
#  'incentives',
#  'income',
#  'increase',
#  'increased',
#  'independent',
#  'indikator',
#  'indikatorindikator',
#  'individu',
#  'individual',
#  'indonesia',
#  'indriasari',
#  'industri',
#  'inferensial',
#  'influence',
#  'informasi',
#  'ingat',
#  'ingin',
#  'ini',
#  'inovasi',
#  'insani',
#  'insanifl',
#  'insentif',
#  'instansi',
#  'institusi',
#  'institut',
#  'instrumen',
#  'instrument',
#  'integrasi',
#  'integritas',
#  'internal',
#  'interval',
#  'interview',
#  'interviews',
#  'inti',
#  'intrepertasi',
#  'intstrumen',
#  'investasi',
#  'is',
#  'islam',
#  'istilah',
#  'isuisu',
#  'it',
#  'italics',
#  'item',
#  'items',
#  'itself',
#  'itu',
#  'iv',
#  'izin',
#  'jabat',
#  'jadi',
#  'jaga',
#  'jahe',
#  'jakarta',
#  'jakartaerlangga',
#  'jakartapt',
#  'jalan',
#  'jalin',
#  'jam',
#  'jan',
#  'jangkau',
#  'januani',
#  'januari',
#  'jarak',
#  'jaring',
#  'jasa',
#  'jasajasa',
#  'jauh',
#  'jauhjauh',
#  'jawab',
#  'jawabkemajuan',
#  'jelas',
#  'jelyta',
#  'jenis',
#  'jenjang',
#  'jenuh',
#  'jernih',
#  'jika',
#  'jl',
#  'jlh',
#  'jns',
#  'job',
#  'jual',
#  'judul',
#  'juga',
#  'jumlah',
#  'jumpa',
#  'jun',
#  'juni',
#  'jurnal',
#  'jurus',
#  'jusmlah',
#  'juta',
#  'kait',
#  'kaji',
#  'kaku',
#  'kala',
#  'kali',
#  'kalimat',
#  'kalipada',
#  'kantor',
#  'karakteristik',
#  'karena',
#  'karier',
#  'karir',
#  'karirpekerjaan',
#  'karyawan',
#  'karyawanberupa',
#  'karyawannya',
#  'karyawanpegawai',
#  'karyawanpegawan',
#  'karyono',
#  'kasim',
#  'kasmir',
#  'kasus',
#  'kata',
#  'kategori',
#  'kaya',
#  'kd',
#  'ke',
#  'keanekaragaman',
#  'kecil',
#  'kedai',
#  'kedala',
#  'keduduk',
#  'kegiatankegiatan',
#  'kehandalan',
#  'keikutsertaan',
#  'kelamin',
#  'kelas',
#  'kelola',
#  'kelomopk',
#  'kelompok',
#  'keluar',
#  'kemanamana',
#  'kemas',
#  'kembali',
#  'kembang',
#  'kemudian',
#  'kena',
#  'kenal',
#  'kendali',
#  'kepada',
#  'kepemipinan',
#  'kerangka',
#  'keras',
#  'kerja',
#  'kerjafl',
#  'kerjasama',
#  'ketua',
#  'keuntunganrp',
#  'keyword',
#  'keywords',
#  'kg',
#  'khas',
#  'khusus',
#  'kimia',
#  'kira',
#  'kita',
#  'km2',
#  'km275',
#  'knowledge',
#  'known',
#  ...]
