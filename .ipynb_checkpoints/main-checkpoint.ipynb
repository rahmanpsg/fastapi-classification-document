# %%
import PyPDF3
import pandas as pd
import numpy as np
import string
import re

# %%
# Membaca teks di dalam dokumen PDF

jurnalFile = open('jurnal/1.pdf', 'rb')

pdfReader = PyPDF3.PdfFileReader(jurnalFile)    

text = ""

for page in pdfReader.pages:
    text += page.extractText()
    
jurnalFile.close()

print(text)
# Out:
# E
# -
# ISSN : 2775
# -
# 412X
# !
# JURNAL
# SINTAKS LOGIKA
#
# Vol.
# 1
#
# No.
# 3
#
# ,
# September
#
# -
#
# 20
# 21
#
#
# https://jurnal.umpar.ac.id/index.php/sylog
#
#
#
# DOI:
# https://doi.
# org/10.31850/jsilog.v1i
# 3
#
#
#
# !
#
# 1
# !
# SISTEM INFORMASI PENGADUAN PELANGGAN PADA
#
# PT. PLN (PERSERO) ULP PANGSID UP 3 PAREPARE BERBASIS WEB
#
#
# !
# Ade Hastuty
# 1
# ,
# Ahmad Selao
# 2
# ,
# Fergiawan HR
# .
#
# Saleh
# 3
#
# 1,
# 2,3
# Program Studi
# ...
# , Universitas Muhammadiyah Parepare, Indonesia
#
# fergiawanhr.saleh95@gmail.com
#
# !
# Informasi Artikel
#
#
# ABSTRACT
#
# Riwayat Artikel:
#
# Dikirim
#
# Author
#
# :
# 9
# -
# 01
# -
# 2021
#
# Diterima
#
# Redaksi
# :
# 10
# -
# 01
# -
# 2021
#
# Revisi
#
# Reviewer
# :
# 12
# -
# 01
# -
# 2021
#
# Diterbitkan
# online
# :
# 18
# -
# 01
# -
# 2021
#
#
#
# This study takes the problem of the PLN Customer Complaint Application. This research
# provides an overview of the accuracy in the process of submitting custom
# er complaints
# and complaints by using a database
# -
# based system. Customer complaints are currently
# still manual, namely coming directly to the PLN office or using Tel 123, a condition that
# occurs is the slow handling due to manual recording. As a result, the
#
# response back to a
# complaint or complaint from customers tends not to be recorded in detail because it has
# not utilized data integrated with computers which makes it difficult to find data, process
# data, and report complaints and complaints. Aims to creat
# e a program that can make it
# easier for the community to report complaints that occur in their environment so as to
# speed up the problem handling process and prepare a customer complaint reporting
# system regarding electricity usage that is integrated with
# data at PT. PLN (Persero)
# ULP Pangsid UP 3 Parepare. The research method used is Field Research and Literature
# Study. The creation of a customer complaint system will provide convenience in using
# electrical facilities. The output of the application is a li
# st of complaint reports, customers,
# and officers that can be printed or downloaded as a PDF file. From the test results using
# the Black Box, by testing the program listing, it was found that the system was running
# successfully after testing the complaint d
# ata input in accordance with the application
# function. From the results of the White Box test testing the program algorithm, it is
# found that the number of flowgraphs with the same number of paths in the white box test
# is declared a logical error
# -
# free appl
# ication. With the Web Hosting System so that the
# resulting customer complaint system PT. PLN (Persero) ULP Pangsid UP3 Parepare
# .
#
# Keywords:
#
# Applications
# ;
# Complaints
# ;
# Customers
# ;
# PLN
# .
#
# ABSTRAK
#
# Kata kunci
# :
#
# Aplikasi;
# Pengaduan; Pela
# nggan; PLN.
#
#
#
#
# Penelitian ini mengambil permasalahan mengenai Aplikasi
# Pengaduan
# Pelanggan PLN
# .
#
# Dalam penelitian ini memberikan pandangan tentang
# keakuratan di dalam proses penyampaian pengaduan dan keluhan pelanggan
# dengan mempergunakan suatu sistem yang telah berbasis database
# .
#
# Pengaduan pelanggan saat ini masih secara manual yaitu datang langsung
# ke
# kantor PLN atau menggunakan Telpon 123
# ,
#
# kondisi yang terjadi lambatnya
# penanganan karena dilakukan pencatatan manual. Akibatnya respon balik
# terhadap suatu pengaduan atau keluhan dari para pelanggan yang cenderung
# tidak terdata secara terperinci karena
# belum memanfaatkan data terintegrasi
# dengan komputer yang mengakibatkan sulitnya pencarian data, pengolahan
# data, serta pelaporan atas keluhan maupun pengaduan.
#
# Bertujuan untuk
# membuat program yang dapat
#
# mempermudah
# masyarakat dalam melaporkan
# kejadian kel
# uhan yang terjadi pada lingkungannya sehingga
#
# mempercepat
# proses penanganan masalah
#
# dan m
# enyiapkan sistem pelaporan keluhan
# pelanggan mengenai penggunaan listrik yang terintegrasi data di PT. PLN
# (Persero) ULP Pangsid UP 3 Parepare
# .
# Metode penelitian yang
# digunakan
# adalah Penelitian Lapangan
# (Field Research) dan Kajian
# Kepustakaan
# (Literature
# Study).
# Output
#
# dari aplikasi adalah daftar laporan pengaduan, pelanggan, dan
# petugas yang dapat dicetak ataupun didownload menjadi file
# PDF
# .
#
# Dari hasil
# pengujian menggunakan
# Black Box,
# dengan menguji listing program diperoleh
# bahwa sistem berhasil berjalan setelah dilak
# ukan pengujian penginputan data
# pengaduan
#
# sesuai dengan fungsi aplikasi. Dari hasil pengujian
# White Box
# menguji algoritma program diperoleh bahwa jumlah flowgraph dengan
# jumlah path pada pengujian white box sama
#
# dinyatakan aplikasi bebas
# kesalahan logika
# .
# Dengan Sistem Web Hosting sehingga dihasilkan sistem
# pengaduan pelanggan PT. PLN
#
# (Persero)
#
# ULP Pangsid UP3 Parepare
# .
#
#
#
#
# JURNAL
# SINTAKS LOGIKA
#
# -
#
# Vol.
# 1
#
# No.
# 1
# ,
# Januari 2021
#
#
# !
#
# 2
# !
# Penulis Korespondensi:
#
# Fergiawan HR
# .
#
# Saleh
# ,
#
# Pro
# gram Studi
# Teknik Informa
# tika
# ,
#
# Universitas Muhammadiyah Parepare,
#
# J
# l. Jend
# e
# ral
#
# Ahmad Yani KM. 6
# , Kota
# Parepare, Indonesia.
#
# Email:
# fergiawanhr.saleh95@gmail.com
#
#
# This is an open access article under the
# CC BY
# -
# SA
#
# license.
#
# I.
# !
# PENDAHULUAN
#
# PT. PLN (Persero) adalah perusahaan yang dimiliki oleh
# pemerintah yang memiliki fungsi penyedia sistem listrik
# nasional yang disalurkan di seluruh Indonesia. PT. PLN
# (Persero)
# adalah perusahaan publik yang bergerak
# dalam layanan sehingga memiliki tanggung jawab besar
# untuk memberikan layanan terbaik kepada masyarakat
#
# (Budi Setiadi, Johan Wahyudi, 2020)
# .
#
# Layanan pengaduan adalah salah satu pihak penting
# dari kegiatan peningkatan kepuasan pelanggan PLN,
# karena bagian Pegaduan Perusahaan memberi
# pelanggan keluhan (keluhan) atau keluhan di mana
# layanan. Mereka menerima tidak sesuai dengan harapan
# atau tidak s
# esuai dengan janji perusahaan. Dalam
# melaksanakan kebutuhan klien yang merupakan tujuan
# penting PLN dalam kepuasan kebutuhan, keinginan
# dan kepuasan kepuasan kebutuhan, keinginan dan klien
# sesuai dengan kualitas layanan yang disediakan oleh
# PLN kepada kons
# umen. Jadi PT. PLN (
# P
# er
# ser
# o) ULP
# Pangsid Up 3
# Parepare
#
# harus ditangkap untuk
# memberikan layanan pelanggan terbaik
#
# (Agun & Iwan,
# 2019)
# .
#
# Pada PT. PLN (Persero) Area Kota Parepare aktifitas
# monitoring pengaduan dan keluhan pelang
# gan saat ini
# masih secara manual yaitu datang langsung ke kantor
# PLN atau menggunakan Telpon 123 kondisi yang terjadi
# lambatnya penanganan karena dilakukan pencatatan
# manual. Akibatnya respon balik terhadap suatu
# pengaduan atau keluhan dari para pelanggan
# yang
# cenderung tidak terdata secara terperinci karena belum
# memanfaatkan data terintegrasi dengan komputer yang
# mengakibatkan sulitnya pencarian data, pengolahan
# data, serta pelaporan atas keluhan maupun pengaduan.
# Oleh karena itu di butuhkan suatu aplikas
# i yang dapat
# menangani semua permasalahan diatas.
#
# B
# erdasarkan uraian diatas, penulis berencana membuat
#
# sebuah ÒSistem Informasi
# Pengaduan
#
# Pelanggan Pada
# PT. PLN (Persero) ULP Pangsid UP 3 Parepare
#
# Berbasis
# WebÓsehingga
#
# mempermudah
# masyarakat dalam
# melaporkan kejadian keluhan yang terjadi pada
# lingkungannya sehingga
#
# mempercepat proses
# penanganan masalah.
#
#
# II.
# !
# METODO
# LOGI
#
# PENELITIAN
#
# !"
# !
# Jenis Penelitian
#
# Adapun Jenis yang digunak
# a
# n dalam
# penelitian ini
# secara tidak langsung dan secara langsung yaitu :
#
# 1)
# !
# Secara Tidak Langsung (Studi Literatur)
#
# Metode tidak langsung ini maksudnya ialah
# mengumpulkan data
# -
# data maupun informasi yang
# terkait seperti mempelajari buku
# -
# buku pustaka atau
# artikel yang
# berasal dari media internet.
#
# 2)
# !
# Secara Langsung (Observasi)
#
# Metode secara langsung yaitu mengumpulkan data
# -
# data
# atau informasi yang terkait dengan perancangan
# program aplikasi berupa pengamatan langsung,
# wawancara dan pengumpulan dokumen.
#
# #"
# !
# Lokasi dan
# Waktu
#
# Adapun
# Pegumpulan data dilakukan di
# PT. PLN
# (Persero) ULP Pangsid UP 3 Parepare
# yang beralamat di
# J
# alan
# Bau Massepe No. 1 Pangkajene Sidrap
#
# S
# a
# ulawesi
# Selatan.
#
# Adapun waktu yang dipergunakan untuk pelaksanaan
# penelitian ini
# adalah sebagai berikut
#
# :
#
# Tabel
# 1.
#
# Waktu Penelitian
#
# No
#
# Kegiatan
#
# Bulan
#
# 11
# -
# 202
# 0
#
# 12
# -
# 202
# 0
#
# 01
# -
# 202
# 1
#
# 02
# -
# 02
# 1
#
# 03
# -
# 202
# 1
#
# 04
# -
# 2
# 02
# 1
#
# 1
#
# Persiapan
# Data
#
#
#
#
#
#
#
# 2
#
# Desain dan
# Pembuatan
# Program
#
#
#
#
#
#
#
# 3
#
# Implementasi
# dan Testing
#
#
#
#
#
#
#
# 4
#
# Penyusunan
# Laporan
#
#
#
#
#
#
#
# $"
# !
# Alat Yang Digunakan
#
# Adapun Alat penelitian yang digunakan selama proses
# penelitian yaitu:
#
# 1)
# !
# Spesifikasi Perangkat Keras
#
# Perangkat keras yang digunakan dalam pembuatan
# sistem adalah sebuah laptop dengan spesifikasi sebagai
# berikut :
#
# Type Processor
#
#
# :
# Intel ¨ Celeron N2830
#
#
#
#
# Ade Hastuty
# ,
# Ahmad Selao
# ,
# Fer
# giawan HR. Saleh
#
# (
# Sistem Informasi Pengadua
# n Pelanggan
# ..
#
#
# !
#
# 3
# !
# Memory
#
#
#
# : 2 GB
#
# Harddisk
#
#
#
# : 500 GB
#
# Printer
#
#
#
# :
# Canon iP2700
#
# Layar LED
#
#
#
# : 14 inci
#
# 2)
# !
# Spesifikasi Perangk
# at Lunak
#
# Perangkat lunak yang digunakan untuk membangun
# aplikasi ini dapat dilihat spesifikasi sebagai berikut :
#
# Sistem Operasi
#
# :
#
# ¥
# !
# Windows 7
#
# Aplikasi yang digunakan
#
# :
#
# ¥
# !
# Google
# Chrome
# , Visual Studio Code, XAMPP
#
# %"
# !
# Teknik Pengumpulan Data
#
# Teknik
# pengumpulan data merupakan cara/metode
# yang digunakan penulis dalam mengumpulkan data.
# Metode pengumpulan data yang digunakan adalah
# sebagai berikut
#
# :
#
# 1)
# !
# Wawancara
# (Inteview)
#
# Metode wawancara/interview kepada para staff
# costumer service yang menangani pengadua
# n
# masyarakat serta petugas PT. PLN (Persero) ULP
# Pangsid UP 3 Parepare untuk menanyakan bagaimana
# penanganan pengaduan masalah kelistrikan.
#
# 2)
# !
# Observasi
#
# Selain itu penulis juga menggunakan metode
# pengumpulan data dengan observasi dengan
# melakukan pengamatan t
# erhadap sistem penanganan
# yang berjalan saat ini.
#
# &"
# !
# Tahapan Penelitian
#
# Adapun tahapan
# Ð
#
# tahapan yang dilakukan sebagai
# berikut :
#
# 1)
# !
# Analisis Data
#
# Pertama, atur data. Data yang dikumpulkan terdiri dari
# catatan lapangan dan dokumen, dalam bentuk laporan,
# biografi, artikel, dll. Pekerjaan analisis data dalam hal
# ini mengkonfigurasi, mengklasifikasikan,
# mengelompokkan, memberikan kode dan
# mengkategorika
# nnya.
#
#
# 2)
# !
# Perancangan Sistem
#
# Dalam bab ini, itu akan membahas desain dan hasil
# program sistem yang telah dibangun. Desain aplikasi ini
# mencakup peningkatan sistematis dan proses sistem
# perangkat lunak yang akan dibangun, kemudian
# merancang aplikasi aplikasi dan aplikasi aplikasi.
#
# 3)
# !
# Pemb
# uatan Program
#
# Membuat analisa terhadap data yang sudah diperoleh
# dilapangan yaitu menggabungkan dengan laporan
# Survey dan kebijakan pemakai menjadi spesifikasi yang
# terstruktur dengan menggunakan pemodelan.
#
# 4)
# !
# Pengujian Aplikasi
#
# Pengujian Perangkat Lunak (bah
# asa Inggris:
# Software
# Testing
# ) adalah investigasi yang dilakukan untuk
# informasi tentang kualitas produk atau layanan yang
# sedang diuji. tes Software juga menyediakan opini yang
# objektif tentang software secara obyektif dan
# independen, yang berguna dalam o
# perasi komersial
# untuk memahami tingkat risiko dalam pelaksanaannya.
#
#
# 5)
# !
# Implementasi
#
# Pada tahap ini, penulis kemudian dikodekan dalam
# bentuk kode program menggunakan bahasa
# pemrograman tertentu sehingga dapat dijalankan pada
# komputer. Dasar dari kegiatan ini adalah pemrograman.
# Alat untuk membuat program yang disebut bahasa
# pemrograman. Pr
# ogrammer membuat program dengan
# panduan dokumentasi desain perangkat lunak, tetapi
# dalam programmer umum juga meninjau semua
# dokumen dari tahapan tahap sebelumnya untuk
# memverifikasi konsistensi dokumentasi yang ada.
#
# 6)
# !
# Metode Pengujian
#
# Metode uji yang diguna
# kan oleh penulis adalah
# Black
# Box
# .
#
#
# III.
# !
# HASIL
#
# DAN
#
# PEMBAHASAN
#
# !"
# !
# Rancangan Sistem
#
# 1)
# !
# Use Case
# Diagram
#
# Sistem Yang Berjalan
#
#
# Gambar
# 1.
#
# Use Case
# Diagram
#
# Sistem Yang Berjalan
#
#
#
#
# JURNAL
# SINTAKS LOGIKA
#
# -
#
# Vol.
# 1
#
# No.
# 1
# ,
# Januari 2021
#
#
# !
#
# 4
# !
# 2)
# !
# Use Case
# Diagram
#
# Sistem Yang Diusulkan
#
#
# Gambar
# 2.
#
# Use Case
#
# Diagram Sistem Yang Diusulkan
#
# Penjelasan
# Use Case
#
# Diagram
#
# :
#
# Tabel
# 2.
#
# Penjelasan
# Use Case Diagram
#
# Nama
# Use Case
#
# Deskripsi
# Use Case
#
# Admin
#
# Aktor
#
# Petugas
#
# Aktor
#
# Pelanggan
#
# Aktor
#
# Login
#
# Use Case
# yang menjelaskan tentang
# proses
# login
#
# sebagai admin/petugas
# untuk ke halaman admin/petugas
#
# Halamat Utama
#
# Use Case
#
# ini menjelaskan tentang
# proses menampilkan halaman utama
# ketika membuka aplikasi
#
# Input
#
# ID
# Pelanggan
#
# Use Case
#
# ini menjelaskan tentang
# proses memasukkan ID Pelanggan
# yang dilakukan oleh pelanggan
#
# Live Chat
#
# Use Case
# ini menjelaskan tentang
# proses melakukan
# Live Chat
#
# antara
# Pelanggan dengan Admin
#
# Input
# Data
# Pengaduan
#
# Use Case
# ini menjelaskan tentang
# proses dimana pelanggan mengisi
# Data Pengaduannya
#
# Daftar
# Pengaduan
#
# Use Case
# ini menjelaskan dimana
# admin
#
# dan petugas dapat melihat
# daftar pengaduan pelanggan
#
# Laporan
#
# Use Case
#
# ini menjelaskan dimana
# admin dapat mencetak laporan.
#
# 3)
# !
# Activity Diag
# ram
#
# a)
# !
# Activity
# Diagram Pelanggan
#
# !
# Gambar
# 3
# .
#
# Activity
#
# Diagram Pelanggan
#
# b)
# !
# Activity
# Diagram
# Admin
#
# !
# Gambar
# 4
# .
#
# Activity
#
# Diagram
#
# Admin
#
#
#
#
# Ade Hastuty
# ,
# Ahmad Selao
# ,
# Fer
# giawan HR. Saleh
#
# (
# Sistem Informasi Pengadua
# n Pelanggan
# ..
#
#
# !
#
# 5
# !
#
# c)
# !
# Activity
# Diagram
#
# Petugas
#
#
# Gambar
# 5.
#
# Activity
#
# Diagram
#
# Petugas
#
# 4)
# !
# S
# equence Diagram
#
# a)
# !
# Sequence
# Diagram Pelanggan
#
#
# Gambar
# 1
# .
#
# Sequence
#
# Diagram
#
# Pelanggan
#
# b)
# !
# Sequence
# Diagram Admin
#
#
# Gambar
# 2
# .
#
# Sequence
#
# Diagram
#
# Admin
#
# c)
# !
# Sequence
# Diagram Petugas
#
#
# Gambar
# 8.
#
# Sequence
#
# Diagram
#
# Petugas
#
# 5)
# !
# Tabel Implementasi
#
# Tabel
# 3.
#
# Tabel User
#
# Tbl_user
#
# No
#
# Name
#
# Type
#
# Size
#
# 1
#
# Username
#
# Varchar
#
# 25
#
# 2
#
# Pasword
#
# Varchar
#
# 25
#
# 3
#
# Nama
#
# Varchar
#
# 25
#
#
#
#
# JURNAL
# SINTAKS LOGIKA
#
# -
#
# Vol.
# 1
#
# No.
# 1
# ,
# Januari 2021
#
#
# !
#
# 6
# !
# 4
#
# Level
#
# Varchar
#
# 10
#
# 5
#
# Data
#
# Longtext
#
# -
#
# 6
#
# Foto
#
# MediumBLOB
#
# -
#
# Tabel
# 4.
#
# Tabel Pelanggan
#
# Tbl_pelanggan
#
# No
#
# Name
#
# Type
#
# Size
#
# 1
#
# ID
#
# Varchar
#
# 12
#
# 2
#
# Nama
#
# Varchar
#
# 25
#
# 3
#
# Jenis_kelamin
#
# Varchar
#
# 20
#
# 4
#
# Alamat
#
# Text
#
# -
#
# 5
#
# Telp
#
# Varchat
#
# 14
#
# Tabel
# 5.
#
# Tabel Pengaduan
#
# Tbl_pengaduan
#
# No
#
# Name
#
# Type
#
# Size
#
# 1
#
# ID
#
# Varchar
#
# 14
#
# 2
#
# Id_pelanggan
#
# Varchar
#
# 12
#
# 3
#
# Nama
#
# Varchar
#
# 25
#
# 4
#
# Telp
#
# Varchar
#
# 14
#
# 5
#
# Pengaduan
#
# Text
#
# -
#
# 6
#
# Lokasi
#
# JSON
#
# -
#
# 7
#
# Status
#
# Varchar
#
# 50
#
# 8
#
# History
#
# JSON
#
# -
#
# 9
#
# Username_petugas
#
# Varchar
#
# 25
#
# #"
# !
# Rancangan Input Program
#
# 1)
# !
# Pela
# nggan
#
# a)
# !
# Halaman Utama
#
# Merupakan halaman utama ketika membuka aplikasi
#
#
# Gambar
# 3
# .
#
# Tampilan Halaman Utama
#
# b)
# !
# Halaman Pengaduan
#
#
# Gambar
# 4
# .
#
# Tampilan Halaman Pengaduan
#
# c)
# !
# Tampilan Live Chat
#
#
# Gambar
# 5
# .
#
# Tampilan
# Live Chat
#
# 2)
# !
# Admin
#
# a)
# !
# Halaman
# Dashboard
#
#
#
#
# Ade Hastuty
# ,
# Ahmad Selao
# ,
# Fer
# giawan HR. Saleh
#
# (
# Sistem Informasi Pengadua
# n Pelanggan
# ..
#
#
# !
#
# 7
# !
#
# Gambar
# 6
# .
#
# Tampilan Halaman
# Dashboard
#
# b)
# !
# Halaman Data Pelanggan
#
#
# Gambar
# 7
# .
#
# Tampilan Halaman Data Pelanggan
#
# c)
# !
# Halaman Data Pengaduan
#
#
# Gambar
# 8
# .
#
# Tampilan Halaman Data Pengaduan
#
# d)
# !
# Halaman
# Live Chat
#
#
# Gambar
# 9
# .
#
# Tampilan Halaman
# Live Chat
#
# e)
# !
# Halaman Data Petugas
#
#
# Gambar
# 10
# .
#
# Tampilan Halaman Data Petugas
#
# f)
# !
# Halaman Laporan
#
#
# Gambar
# 11
# .
#
# Tampilan Halaman Laporan
#
# 3)
# !
# Petugas
#
# a)
# !
# Halaman
# Dashboard
#
#
#
#
# JURNAL
# SINTAKS LOGIKA
#
# -
#
# Vol.
# 1
#
# No.
# 1
# ,
# Januari 2021
#
#
# !
#
# 8
# !
#
# Gambar
# 12
# .
#
# Tampilan Halaman
# Dashboard
#
# b)
# !
# Data Pelanggan
#
#
# Gambar
# 13
# .
#
# Tampilan Halaman Data Pelanggan
#
# c)
# !
# Data Pengaduan
#
#
# Gambar
# 14
# .
#
# Tampilan Halaman Data Pengaduan
#
# d)
# !
# Pengaturan Akun
#
#
# Gambar
# 15
# .
#
# Tampilan Halaman Pengaturan Akun
#
# $"
# !
# Metode Peng
# ujian
#
# Pengujian sistem merupakan proses eksekusi suatu
# program atau sistem secara keseluruhan. Pengujian
# menunjukkan bahwa fungsi dari perangkat lunak
# bekerja sesuai dengan
# spesifikasi dan bahwa
# persyaratan kinerja telah dipenuhi.
#
# Metode pengujian yang digunakan ada
# black
# -
# box
# .
# Pengujian
# blackbox
#
# perangkat lunak dilakukan untuk
# memperlihatkan bahwa masing
# -
# masing fungsi telah
# beroperasi sepenuhnya dan secara bersamaan pula
# mencari kesalahan pada setiap fungsi.
#
#
# IV.
# !
# K
# E
# SIMPULAN
#
# B
# e
# rdasarkan
#
# hasil penelitian dan pembahasan yang
# telah diuraikan pada bab
# -
# bab sebelumnya,
# Dihasilkannya sebuah
# Aplikasi
# pelayanan gangguan
# listrik berbasis
# web
#
# di
# PT. PLN (Persero) ULP Pangsid
# UP 3 Parepare
#
# dengan menggunakan bahasa
# pemrograman
# PHP
# dan
# Javascript
#
# untu
# k Databasenya
# menggunakan
# Mysql
# . Pe
# layanan pengaduan pelanggan
#
# dengan cara online akan lebih efektif dan efesien
# ,
# sehingga
#
# dapat dipantau secara berkala oleh
# operator
# PLN
# ULP Pangsid
#
# UP 3. Aplikasi yang dibuat sudah
# bebas dari kesalahan karena diuji dengan menggunakan
# dua teknik pengujian yaitu pengujian
# Black Box
#
# dan
# pengujian
# White Box
# .
# Maka dapat ditarik kesimpulan
# sebagai berikut :
#
# 1.
# !
# Untuk membua
# t
#
# Aplikasi
# pelayanan gangguan
# listrik
#
# berbasis
# web
#
# di PT. PLN
# ULP Pangsid UP 3
# Parepare
#
# telah dibuktikan dengan menggunakan
# metode Pengujian
# Black Box
#
# menyatakan aplikasi
# yang dihasilkan sudah berjalan sesuai dengan
# kebutuhan dan bebas dari kesalahan dan pegujian
# White Box Testing
# untuk mendapatkan cara kerja
# program secara rinci. Pada pengujiannya, struktur
# logika dipetakan dengan
# Flowchart
# dan
# Flowgra
# ph
# kemudian jumlah edge dan nodenya dijumlahkan
#
#
#
# Ade Hastuty
# ,
# Ahmad Selao
# ,
# Fer
# giawan HR. Saleh
#
# (
# Sistem Informasi Pengadua
# n Pelanggan
# ..
#
#
# !
#
# 9
# !
# sehingga memperoleh nilai
# Cyclometic Complexcity.
# Berdasarkan hasil pengujian pada login,
# home,inputdata,edit data,hapus data,
# download
#
# laporan pengaduan
#
# diperoleh nilai
# Independent
# Path, Region, dan Cyclomat
# ic Complexity
#
# bernilai
# sama sehingga dapat dikatakan aplikasi yang
# dibuat sudah berjalan sesuai dengan kebutuhan.
#
#
# 2.
# !
# Aplikasi
# Dengan mengupload
#
# pengaduan
# gangguan listrik
#
# secara
# online
#
# maka dapat dipantau
# secara
# uptodate
#
# oleh pihak
# PLN
# dan dapat
# meminimalisir permasalahan dalam melaksanakan
# p
# erbaikan
#
# tersebut karena ketika terjadi
# keterlambatan pengerjaan maka dapat lebih cepat
# dilakukan tindakan lebih lanjut.
#
# REFERENSI
#
# [1]
# !
# Abdulloh, R. (2015).
# Web Programming is Easy.
#
# Jakarta: PT Elex
# Media Komputindo.
#
# [2]
# !
# Agun, I., & Iwan, B. S. (2019, Oktober 2). Analisis Pelayanan
# Bagian Pengaduan di Kantor PT PLN (Persero) Unit Induk
# Wilayah Aceh.
# Journal of Economics Science Vol. 5 No. 2
# .
#
# [3]
# !
# Anggaraeni, E. Y., & Irviani. (2017).
# Pengantar Sistem Informasi.
#
# Yogyakarta: Andi
# .
#
# [4]
# !
# Ariani, S. R., & Shalahuddin, M. (2016).
# Rekayasa Perangkat Lunak.
#
# Bandung: Informatika.
#
# [5]
# !
# Bekti, B. H. (2015).
# Mahir Membuat Website dengan Adobe
# Dreamweaver CS6, CSS dan jQuery.
#
# Yogyakarta: Andi.
#
# [6]
# !
# Bell, S. J., & Luddington, J. A. (2016). Coping With Custo
# mer
# Complaints.
# Journal of Service Research
# .
#
# [7]
# !
# Budi Setiadi, Johan Wahyudi. (2020, Oktober). Aplikasi
# Monitoring Pengaduan dan Keluhan Pelanggan Pada PT. PLN
# (Persero) Area Banjarmasin Berbasis Web.
# Technologia Vol 11, No.
# 4
# , hal. 234
# -
# 239.
#
# [8]
# !
# Darmajaya, J. B. (
# 2016). Pengaruh Penanganan Keluhan
# (Complaint Handling) Terhadap Kepercayaan dan Komitmen
# Mahasiswa.
# Jurnal Bisnis Darmajaya
# , 1
# -
# 13.
#
# [9]
# !
# Daryanto, & Setyobudi, I. (2014).
# Konsumen dan Pelayanan Prima.
#
# Yogyakarta: Gava Media.
#
# [10]
# !
# Lubis, B. O. (2016). Penerapan Globa
# l Extreme Porgramming
# Pada SIstem Informasi Workshop, Seminar dan Pelatigan di
# Lembaga Edukasi.
# Jurnal Informatika
# , hal. 234
# -
# 246.
#
# [11]
# !
# Madcoms. (2016).
# Sukses Membangun Toko Online dengan PHP dan
# MySQL.
#
# Yogyakarta: Gava Media.
#
# [12]
# !
# Mulyadi. (2016).
# Sistem Informasi
# Akuntasi.
#
# Jakarta: Salemba
# Empat.
#
# [13]
# !
# Mustaqbal, M. S., Firdaus, R. F., & Rahmadi, H. (2015).
# Pengujian
# Aplikasi Menggunakan Black Box Testing Boundary Value Analysis.
#
# Bandung: Jurnal Ilmiah Teknologi Informasi Terapan.
#
# [14]
# !
# Purbadian, Y. (2016).
# Trik Cepat Membang
# un Aplikasi Berbasis Web
# dengan Framework CodeIgniter.
#
# Yogyakarta: Andi.
#
# [15]
# !
# Raharjo, B. (2015).
# Belajar Otodidak MySql.
#
# Bandung: Informatika.
#
# [16]
# !
# Romney, M. B., & Steinbart. (2015).
# Sistem Informasi Akuntasi.
#
# Jakarta: Salemba Empat.
#
# [17]
# !
# Rosa, A. S., & Shalahudding, M. (2015).
# Rekayasa Perangkat Lunak
# Terstruktur dan Berorientasi Objek.
#
# Bandung: Informatika.
#
# [18]
# !
# Solichin, A. (2016).
# Pemrograman Web dengan PHP dan MySQL.
#
# Jakarta: Budi Luhur.
#
# [19]
# !
# Supono, & Putratama, V. (2016).
# Pemrograman Web dengan
# Menggunakan PHP dan Framework CodeIgniter.
#
# Yogyakarta:
# Deepublish.
#
# [20]
# !
# Tim, E. (2016).
# All in One Web Programming.
#
# Jakarta: PT Elex
# Media Komputindo.
#
# [21]
# !
# Trimahardhika, R., & Sutinah, E. (2017). Development Da
# lam
# Perancangan Sistem Informasi Perpustakaan.
# Jurnal Informatika
# ,
# 250.
#
# [22]
# !
# Wahana, Komputer. (2015).
# Webmaster Menguasai CSS.
#
# Yogyakarta: Andi.
#
# [23]
# !
# Winarno, E., Zaki, A., & SmitDev, C. (2014).
# Javascript, jQuery,
# dan jQuery Mobile.
#
# Semarang: PT Elex Media Komputi
# ndo.

# %%
## fungsi untuk menghapus url didalam teks
def remove_URL(text):
    url = re.compile(r"https?://\S+|www\.\S+")
    return url.sub(r"",text)

## fungsi untuk menghapus tanda baca didalam teks
def remove_punct(text):
    translator = str.maketrans("", "", string.punctuation)
    return text.translate(translator)

## fungsi untuk mengubah teks menjadi huruf kecil
def case_folding(text):
    return text.casefold()

# %%
## stopwords
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

stopwords = StopWordRemoverFactory().create_stop_word_remover()

def remove_stopwords(text):
    return stopwords.remove(text)

# %%
## stemming
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

stemmer = StemmerFactory().create_stemmer()

def stemming(text):
    return stemmer.stem(text)

# %%
# Preprocessing

text = remove_punct(text)
text = case_folding(text)
text = remove_stopwords(text)
text = stemming(text)

print(text)
# Out:
# e issn 2775 412x jurnal sintaks logika vol 1 no 3 september 20 21 httpsjurnalumparacidindexphpsylog doi httpsdoi org1031850jsilogv1i 3 1 sistem informasi adu langgan pt pln persero ulp pangsid up 3 parepare bas web ade hastuty 1 ahmad selao 2 fergiawan hr saleh 3 1 23 program studi universitas muhammadiyah parepare indonesia fergiawanhrsaleh95gmailcom informasi artikel abstract riwayat artikel kirim author 9 01 2021 terima redaksi 10 01 2021 revisi reviewer 12 01 2021 terbit online 18 01 2021 this study takes the problem of the pln customer complaint application this research provides an overview of the accuracy in the process of submitting custom er complaints and complaints by using a database based system customer complaints are currently still manual namely coming directly to the pln office or using tel 123 a condition that occurs is the slow handling due to manual recording as a result the response back to a complaint or complaint from customers tends not to be recorded in detail because it has not utilized data integrated with computers which makes it difficult to find data process data and report complaints and complaints aims to creat e a program that can make it easier for the community to report complaints that occur in their environment so as to speed up the problem handling process and prepare a customer complaint reporting system regarding electricity usage that is integrated with data at pt pln persero ulp pangsid up 3 parepare the research method used is field research and literature study the creation of a customer complaint system will provide convenience in using electrical facilities the output of the application is a li st of complaint reports customers and officers that can be printed or downloaded as a pdf file from the test results using the black box by testing the program listing it was found that the system was running successfully after testing the complaint d ata input in accordance with the application function from the results of the white box test testing the program algorithm it is found that the number of flowgraphs with the same number of paths in the white box test is declared a logical error free appl ication with the web hosting system so that the resulting customer complaint system pt pln persero ulp pangsid up3 parepare keywords applications complaints customers pln abstrak kata kunci aplikasi adu pela nggan pln teliti ambil masalah kena aplikasi adu langgan pln teliti beri pandang akurat proses adu keluh langgan suatu sistem bas database adu langgan manual datang langsung kantor pln telpon 123 kondisi jadi lambat tangan laku catat manual akibat respon balik hadap suatu adu keluh langgan cenderung data perinci manfaat data integrasi komputer akibat sulit cari data olah data lapor atas keluh maupun adu tuju buat program mudah masyarakat lapor jadi kel uhan jadi lingkung cepat proses tangan masalah m enyiapkan sistem lapor keluh langgan kena listrik integrasi data pt pln persero ulp pangsid up 3 parepare metode teliti teliti lapang field research kaji pustaka literature study output aplikasi daftar lapor adu langgan tugas cetak didownload jadi file pdf hasil uji black box uji listing program sistem hasil jalan dilak ukan uji penginputan data adu sesuai fungsi aplikasi hasil uji white box uji algoritma program jumlah flowgraph jumlah path uji white box sama nyata aplikasi bebas salah logika sistem web hosting hasil sistem adu langgan pt pln persero ulp pangsid up3 parepare jurnal sintaks logika vol 1 no 1 januari 2021 2 tulis korespondensi fergiawan hr saleh pro gram studi teknik informa tika universitas muhammadiyah parepare j l jend e ral ahmad yani km 6 kota parepare indonesia email fergiawanhrsaleh95gmailcom this is an open access article under the cc by sa license i pt pln persero usaha milik perintah milik fungsi sedia sistem listrik nasional salur seluruh indonesia pt pln persero usaha publik gerak layan milik tanggung jawab besar beri layan baik masyarakat budi setiadi johan wahyudi  ...

# %%
# Memecah setiap kata

keywords = re.findall(r'[a-zA-Z]\w+',text)

# Jumlah kata
len(keywords)

# %%
# Filter data yang sama dan menyimpan di DataFrame

df = pd.DataFrame(list(set(keywords)),columns=['keywords'])

df['keywords']
# Out:
# 0          teknik
# 1         varchar
# 2            cara
# 3          mereka
# 4            andi
#           ...
# 839      objektif
# 840         dapat
# 841           for
# 842         selao
# 843    penelitian
# Name: keywords, Length: 844, dtype: object

# %%
# Preprocessing
# df['keywords'] = df.keywords.map(remove_punct)
# df['keywords'] = df.keywords.map(case_folding)
# df['keywords'] = df.keywords.map(remove_stopwords)
# df['keywords'] = df.keywords.map(stemming)

# df['keywords']
# Out:
# 0        teknik
# 1       varchar
# 2          cara
# 3
# 4          andi
#          ...
# 839    objektif
# 840
# 841         for
# 842       selao
# 843      teliti
# Name: keywords, Length: 844, dtype: object

# %%
def weightage(word,text,number_of_documents=1):
    word_list = re.findall(word,text)
    number_of_times_word_appeared =len(word_list)
    tf = number_of_times_word_appeared/float(len(text))
    idf = np.log((number_of_documents)/float(number_of_times_word_appeared))
    tf_idf = tf*idf
    return number_of_times_word_appeared,tf,idf ,tf_idf

# %%
df['total kemunculan'] = df['keywords'].apply(lambda x: weightage(x,text)[0])
df['tf'] = df['keywords'].apply(lambda x: weightage(x,text)[1])
df['idf'] = df['keywords'].apply(lambda x: weightage(x,text)[2])
df['tf_idf'] = df['keywords'].apply(lambda x: weightage(x,text)[3])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 df['total kemunculan'] = df['keywords'].apply(lambda x: weightage(x,text)[0])
#       2 df['tf'] = df['keywords'].apply(lambda x: weightage(x,text)[1])
#       3 df['idf'] = df['keywords'].apply(lambda x: weightage(x,text)[2])
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/series.py:4430, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4320 def apply(
#    4321     self,
#    4322     func: AggFuncType,
#    (...)
#    4325     **kwargs,
#    4326 ) -> DataFrame | Series:
#    4327     """
#    4328     Invoke function on values of Series.
#    4329
#    (...)
#    4428     dtype: float64
#    4429     """
# -> 4430     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [11], in <lambda>(x)
# ----> 1 df['total kemunculan'] = df['keywords'].apply(lambda x: weightage(x,text)[0])
#       2 df['tf'] = df['keywords'].apply(lambda x: weightage(x,text)[1])
#       3 df['idf'] = df['keywords'].apply(lambda x: weightage(x,text)[2])
#
# Input In [10], in weightage(word, text, number_of_documents)
#       3 number_of_times_word_appeared =len(word_list)
#       4 tf = number_of_times_word_appeared/float(len(text))
# ----> 5 idf = np.log((number_of_documents)/float(number_of_times_word_appeared))
#       6 tf_idf = tf*idf
#       7 return number_of_times_word_appeared,tf,idf ,tf_idf
#
# ZeroDivisionError: float division by zero

# %%
df = df.sort_values('tf_idf',ascending=True)
df.to_csv('Keywords.csv')
df.head(25)
